# %%
import os
import json

import opensim as osim
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# %% [markdown]
# # Notes:
# - `R_HJC` & `L_HJC` don't exist in the `lenhart2015.osim` model. They were removed from the `marker_weights.json`
#     - `R.Scapula` & `L.Scapula`
#     - `R.Th4`
#     - `L.SH4`
# - Created a new external loads file in this directory that correctly points to the path of the GRF data:
#     `comak.set_external_loads_file('./overground_17_ext_loads.xml')`

# %%
matlab_path = os.path.abspath('../../../../matlab/')
models_path = os.path.abspath('../../../../models')

# model_file = os.path.join(models_path, 'knee_healthy', 'lenhart2015', 'lenhart2015.osim')

model_file = "/root/jam-resources/models/knee_healthy/lenhart2015/lenhart2015.osim";
coordinates_file = "/root/jam-resources/python/examples/Walking/Walking/results/comak-inverse-kinematics/overground_17_ik.mot";
external_loads_file = "/root/jam-resources/python/examples/Walking/Walking/overground_17_ext_loads.xml";
forceset_file =  "/root/jam-resources/models/knee_healthy/lenhart2015/lenhart2015_reserve_actuators.xml";
comak_result_dir = "/root/jam-resources/python/examples/Walking/Walking/results/comak";
results_basename = "walking";
save_xml_path = "/root/jam-resources/python/examples/Walking/Walking/inputs/comak_settings.xml";


# results_basename = 'walking'
ik_result_dir = './results/comak-inverse-kinematics'
# comak_result_dir = './results/comak'
jnt_mech_result_dir = './results/joint-mechanics'

os.makedirs('./inputs', exist_ok=True)
os.makedirs('./results/graphics', exist_ok=True)

with open('./marker_weights.json', 'r') as f:
    marker_weights = json.load(f)

with open('./prescribed_coordinates.json', 'r') as f:
    prescribed_coordinates = json.load(f)

with open('./primary_coordinates.json', 'r') as f:
    primary_coordinates = json.load(f)

with open('./secondary_coordinates.json', 'r') as f:
    secondary_coordinates = json.load(f)

# %% [markdown]
# ### comak_ik setting

# %%
# Settings
perform_secondary_constraint_sim = True
secondary_constraint_sim_settle_threshold = 1e-4
secondary_constraint_sim_sweep_time = 3.0
secondary_coupled_coordinate_start_value = 0
secondary_coupled_coordinate_stop_value = 100
secondary_constraint_sim_integrator_accuracy = 1e-2
secondary_constraint_sim_internal_step_limit = 10000
constraint_function_num_interpolation_points = 20
print_secondary_constraint_sim_results = True
perform_inverse_kinematics = True

report_errors = True
report_marker_locations = False
ik_constraint_weight = 100
ik_accuracy = 1e-5
use_visualizer = False

# %%
comak_ik = osim.COMAKInverseKinematicsTool();
comak_ik.set_model_file(model_file);
comak_ik.set_results_directory(ik_result_dir);
comak_ik.set_results_prefix(results_basename);
comak_ik.set_perform_secondary_constraint_sim(perform_secondary_constraint_sim);
comak_ik.set_secondary_coordinates(0,'/jointset/knee_r/knee_add_r');
comak_ik.set_secondary_coordinates(1,'/jointset/knee_r/knee_rot_r');
comak_ik.set_secondary_coordinates(2,'/jointset/knee_r/knee_tx_r');
comak_ik.set_secondary_coordinates(3,'/jointset/knee_r/knee_ty_r');
comak_ik.set_secondary_coordinates(4,'/jointset/knee_r/knee_tz_r');
comak_ik.set_secondary_coordinates(5,'/jointset/pf_r/pf_flex_r');
comak_ik.set_secondary_coordinates(6,'/jointset/pf_r/pf_rot_r');
comak_ik.set_secondary_coordinates(7,'/jointset/pf_r/pf_tilt_r');
comak_ik.set_secondary_coordinates(8,'/jointset/pf_r/pf_tx_r');
comak_ik.set_secondary_coordinates(9,'/jointset/pf_r/pf_ty_r');
comak_ik.set_secondary_coordinates(10,'/jointset/pf_r/pf_tz_r');
comak_ik.set_secondary_coupled_coordinate('/jointset/knee_r/knee_flex_r');
comak_ik.set_secondary_constraint_sim_settle_threshold(secondary_constraint_sim_settle_threshold);
comak_ik.set_secondary_constraint_sim_sweep_time(secondary_constraint_sim_sweep_time);
comak_ik.set_secondary_coupled_coordinate_start_value(secondary_coupled_coordinate_start_value);
comak_ik.set_secondary_coupled_coordinate_stop_value(secondary_coupled_coordinate_stop_value);
comak_ik.set_secondary_constraint_sim_integrator_accuracy(secondary_constraint_sim_integrator_accuracy);
comak_ik.set_secondary_constraint_sim_internal_step_limit(secondary_constraint_sim_internal_step_limit);
comak_ik.set_secondary_constraint_function_file(
    './results/comak-inverse-kinematics/secondary_coordinate_constraint_functions.xml');
comak_ik.set_constraint_function_num_interpolation_points(constraint_function_num_interpolation_points);
comak_ik.set_print_secondary_constraint_sim_results(print_secondary_constraint_sim_results);
comak_ik.set_constrained_model_file('./results/comak-inverse-kinematics/ik_constrained_model.osim');
comak_ik.set_perform_inverse_kinematics(perform_inverse_kinematics);
comak_ik.set_marker_file(os.path.join(models_path, 'knee_healthy/experimental_data/motion_analysis/overground_17.trc'));

comak_ik.set_output_motion_file('overground_17_ik.mot');
comak_ik.set_time_range(0, 0);
comak_ik.set_time_range(1, 2.36);
comak_ik.set_report_errors(report_errors);
comak_ik.set_report_marker_locations(report_marker_locations);
comak_ik.set_ik_constraint_weight(ik_constraint_weight);
comak_ik.set_ik_accuracy(ik_accuracy);
comak_ik.set_use_visualizer(use_visualizer);
# comak_ik.set_verbose(10);

# %%
ik_task_set = comak_ik.get_IKTaskSet()

# %%
ik_task_set = osim.IKTaskSet()
ik_task = osim.IKMarkerTask()

for marker, weight in marker_weights.items():
    ik_task.setName(marker)
    ik_task.setWeight(weight)
    ik_task_set.cloneAndAppend(ik_task)

# %%
comak_ik.set_IKTaskSet(ik_task_set)
comak_ik.printToXML('./inputs/comak_inverse_kinematics_settings.xml')

print('Running COMAKInverseKinematicsTool...')
comak_ik.run();
# Out:
# Running COMAKInverseKinematicsTool...
# [critical]
# [critical] ==========================
# [critical] COMAKInverseKinematicsTool
# [critical] ==========================
# [critical]
# [info] Loaded model lenhart2015 from file /root/jam-resources/models/knee_healthy/lenhart2015/lenhart2015.osim
# [info] Secondary Coordinates:
# [info] ----------------------
# [info] knee_add_r
# [info] knee_rot_r
# [info] knee_tx_r
# [info] knee_ty_r
# [info] knee_tz_r
# [info] pf_flex_r
# [info] pf_rot_r
# [info] pf_tilt_r
# [info] pf_tx_r
# [info] pf_ty_r
# [info] pf_tz_r
# [info] Secondary Coupled Coordinate:
# [info] Settle Threshold: 0.000100000
# [info] Sweep Time: 3.0
# [info] Sweep secondary_coupled_coordinate start value: 0.0
# [info] Sweep secondary_coupled_coordinate stop value: 100.0
# [info] Performing IK Secondary Constraint Simulation...
# [info] Starting Settling Simulation.
# [info] Time: 0.01
# [info] Name                           Value                Value Change
# [info] knee_add_r                     -0.00184684          0.0
# [info] knee_rot_r                     0.000398628          0.0
# [info] knee_tx_r                      0.000188040          0.0
# [info] knee_ty_r                      0.00230352           0.0
# [info] knee_tz_r                      -0.000676228         0.0
# [info] pf_flex_r                      0.000110427          0.0
# [info] pf_rot_r                       -0.000115522         0.0
# [info] pf_tilt_r                      -0.000268765         0.0
# [info] pf_tx_r                        0.0516001            0.0
# [info] pf_ty_r                        0.00799171           0.0
# [info] pf_tz_r                        0.00485153           0.0
# [info] Finished Settling Simulation in 0.01 s.
# [info] Starting Sweep Simulation.
# [info] 0.0
# [info] 0.01
# [info] 0.02
# [info] 0.03
# [info] 0.04
# [info] 0.05
# [info] 0.06
# [info] 0.07
# [info] 0.08
# [info] 0.09
# [info] 0.1
# [info] 0.11
# [info] 0.12
# [info] 0.13
# [info] 0.14
# [info] 0.15
# [info] 0.16
# [info] 0.17
# [info] 0.18
# [info] 0.19
# [info] 0.2
# [info] 0.21
# [info] 0.22
# [info] 0.23
# [info] 0.24
# [info] 0.25
# [info] 0.26
# [info] 0.27
# [info] 0.28
# [info] 0.29
# [info] 0.3
# [info] 0.31
# [info] 0.32
# [info] 0.33
# [info] 0.34
# [info] 0.35
# [info] 0.36
# [info] 0.37
# [info] 0.38
# [info] 0.39
# [info] 0.4
# [info] 0.41
# [info] 0.42
# [info] 0.43
# [info] 0.44
# [info] 0.45
# [info] 0.46
# [info] 0.47
# [info] 0.48
# [info] 0.49
# [info] 0.5
# [info] 0.51
# [info] 0.52
# [info] 0.53
# [info] 0.54
# [info] 0.55
# [info] 0.56
# [info] 0.57
# [info] 0.58
# [info] 0.59
# [info] 0.6
# [info] 0.61
# [info] 0.62
# [info] 0.63
# [info] 0.64
# [info] 0.65
# [info] 0.66
# [info] 0.67
# [info] 0.68
# [info] 0.69
# [info] 0.7
# [info] 0.71
# [info] 0.72
# [info] 0.73
# [info] 0.74
# [info] 0.75
# [info] 0.76
# [info] 0.77
# [info] 0.78
# [info] 0.79
# [info] 0.8
# [info] 0.81
# [info] 0.82
# [info] 0.83
# [info] 0.84
# [info] 0.85
# [info] 0.86
# [info] 0.87
# [info] 0.88
# [info] 0.89
# [info] 0.9
# [info] 0.91
# [info] 0.92
# [info] 0.93
# [info] 0.94
# [info] 0.95
# [info] 0.96
# [info] 0.97
# [info] 0.98
# [info] 0.99
# [info] 1.0
# [info] 1.01
# [info] 1.02
# [info] 1.03
# [info] 1.04
# [info] 1.05
# [info] 1.06
# [info] 1.07
# [info] 1.08
# [info] 1.09
# [info] 1.1
# [info] 1.11
# [info] 1.12
# [info] 1.13
# [info] 1.14
# [info] 1.15
# [info] 1.16
# [info] 1.17
# [info] 1.18
# [info] 1.19
# [info] 1.2
# [info] 1.21
# [info] 1.22
# [info] 1.23
# [info] 1.24
# [info] 1.25
# [info] 1.26
# [info] 1.27
# [info] 1.28
# [info] 1.29
# [info] 1.3
# [info] 1.31
# [info] 1.32
# [info] 1.33
# [info] 1.34
# [info] 1.35
# [info] 1.36
# [info] 1.37
# [info] 1.38
# [info] 1.39
# [info] 1.4
# [info] 1.41
# [info] 1.42
# [info] 1.43
# [info] 1.44
# [info] 1.45
# [info] 1.46
# [info] 1.47
# [info] 1.48
# [info] 1.49
# [info] 1.5
# [info] 1.51
# [info] 1.52
# [info] 1.53
# [info] 1.54
# [info] 1.55
# [info] 1.56
# [info] 1.57
# [info] 1.58
# [info] 1.59
# [info] 1.6
# [info] 1.61
# [info] 1.62
# [info] 1.63
# [info] 1.64
# [info] 1.65
# [info] 1.66
# [info] 1.67
# [info] 1.68
# [info] 1.69
# [info] 1.7
# [info] 1.71
# [info] 1.72
# [info] 1.73
# [info] 1.74
# [info] 1.75
# [info] 1.76
# [info] 1.77
# [info] 1.78
# [info] 1.79
# [info] 1.8
# [info] 1.81
# [info] 1.82
# [info] 1.83
# [info] 1.84
# [info] 1.85
# [info] 1.86
# [info] 1.87
# [info] 1.88
# [info] 1.89
# [info] 1.9
# [info] 1.91
# [info] 1.92
# [info] 1.93
# [info] 1.94
# [info] 1.95
# [info] 1.96
# [info] 1.97
# [info] 1.98
# [info] 1.99
# [info] 2.0
# [info] 2.01
# [info] 2.02
# [info] 2.03
# [info] 2.04
# [info] 2.05
# [info] 2.06
# [info] 2.07
# [info] 2.08
# [info] 2.09
# [info] 2.1
# [info] 2.11
# [info] 2.12
# [info] 2.13
# [info] 2.14
# [info] 2.15
# [info] 2.16
# [info] 2.17
# [info] 2.18
# [info] 2.19
# [info] 2.2
# [info] 2.21
# [info] 2.22
# [info] 2.23
# [info] 2.24
# [info] 2.25
# [info] 2.26
# [info] 2.27
# [info] 2.28
# [info] 2.29
# [info] 2.3
# [info] 2.31
# [info] 2.32
# [info] 2.33
# [info] 2.34
# [info] 2.35
# [info] 2.36
# [info] 2.37
# [info] 2.38
# [info] 2.39
# [info] 2.4
# [info] 2.41
# [info] 2.42
# [info] 2.43
# [info] 2.44
# [info] 2.45
# [info] 2.46
# [info] 2.47
# [info] 2.48
# [info] 2.49
# [info] 2.5
# [info] 2.51
# [info] 2.52
# [info] 2.53
# [info] 2.54
# [info] 2.55
# [info] 2.56
# [info] 2.57
# [info] 2.58
# [info] 2.59
# [info] 2.6
# [info] 2.61
# [info] 2.62
# [info] 2.63
# [info] 2.64
# [info] 2.65
# [info] 2.66
# [info] 2.67
# [info] 2.68
# [info] 2.69
# [info] 2.7
# [info] 2.71
# [info] 2.72
# [info] 2.73
# [info] 2.74
# [info] 2.75
# [info] 2.76
# [info] 2.77
# [info] 2.78
# [info] 2.79
# [info] 2.8
# [info] 2.81
# [info] 2.82
# [info] 2.83
# [info] 2.84
# [info] 2.85
# [info] 2.86
# [info] 2.87
# [info] 2.88
# [info] 2.89
# [info] 2.9
# [info] 2.91
# [info] 2.92
# [info] 2.93
# [info] 2.94
# [info] 2.95
# [info] 2.96
# [info] 2.97
# [info] 2.98
# [info] 2.99
# [info] 3.0
# [info] Printing secondary constraint simulation results: ./results/comak-inverse-kinematics
#
#                MODEL: lenhart2015
#          coordinates: 52
#               forces: 134
#            actuators: 44
#              muscles: 44
#             analyses: 0
#               probes: 0
#               bodies: 25
#               joints: 25
#          constraints: 11
#              markers: 39
#          controllers: 0
#   contact geometries: 3
# misc modelcomponents: 0
# [info] Running Inverse Kinematics
#
# Frame 0 (t=0):	total squared error = 0.0206225, marker error: RMS=0.0229952, max=0.0690157 (L.SH2)
# Frame 1 (t=0.005):	total squared error = 0.0201648, marker error: RMS=0.0227387, max=0.0603458 (L.SH2)
# Frame 2 (t=0.01):	total squared error = 0.0183047, marker error: RMS=0.0216645, max=0.0506213 (L.SH2)
# Frame 3 (t=0.015):	total squared error = 0.0182729, marker error: RMS=0.0216457, max=0.0485707 (R.Elbow)
# Frame 4 (t=0.02):	total squared error = 0.0170382, marker error: RMS=0.0209016, max=0.0442627 (R.Elbow)
# Frame 5 (t=0.025):	total squared error = 0.0175476, marker error: RMS=0.0212117, max=0.0463295 (R.Elbow)
# Frame 6 (t=0.03):	total squared error = 0.0175162, marker error: RMS=0.0211928, max=0.0413002 (R.Elbow)
# Frame 7 (t=0.035):	total squared error = 0.0170247, marker error: RMS=0.0208933, max=0.0435235 (R.Elbow)
# Frame 8 (t=0.04):	total squared error = 0.0176222, marker error: RMS=0.0212568, max=0.0411774 (L.Bicep)
# Frame 9 (t=0.045):	total squared error = 0.017223, marker error: RMS=0.0210146, max=0.0417305 (R.Elbow)
# Frame 10 (t=0.05):	total squared error = 0.0179638, marker error: RMS=0.0214618, max=0.0408212 (L.Bicep)
# Frame 11 (t=0.055):	total squared error = 0.018265, marker error: RMS=0.021641, max=0.0417346 (L.Bicep)
# Frame 12 (t=0.06):	total squared error = 0.0183353, marker error: RMS=0.0216826, max=0.040999 (L.Bicep)
# Frame 13 (t=0.065):	total squared error = 0.0186912, marker error: RMS=0.0218921, max=0.0416426 (L.Bicep)
# Frame 14 (t=0.07):	total squared error = 0.0187727, marker error: RMS=0.0219397, max=0.0409237 (L.Bicep)
# Frame 15 (t=0.075):	total squared error = 0.0192874, marker error: RMS=0.0222384, max=0.0418215 (L.Bicep)
# Frame 16 (t=0.08):	total squared error = 0.0192934, marker error: RMS=0.0222419, max=0.0416156 (L.Bicep)
# Frame 17 (t=0.085):	total squared error = 0.0202934, marker error: RMS=0.0228111, max=0.0470327 (L.Wrist)
# Frame 18 (t=0.09):	total squared error = 0.0197876, marker error: RMS=0.022525, max=0.0422038 (L.Bicep)
# Frame 19 (t=0.095):	total squared error = 0.0208583, marker error: RMS=0.0231263, max=0.047942 (L.Wrist)
# Frame 20 (t=0.1):	total squared error = 0.0214967, marker error: RMS=0.0234776, max=0.0461577 (L.Bicep)
# Frame 21 (t=0.105):	total squared error = 0.020564, marker error: RMS=0.0229626, max=0.0429008 (L.Bicep)
# Frame 22 (t=0.11):	total squared error = 0.0200121, marker error: RMS=0.0226524, max=0.0404846 (L.Wrist)
# Frame 23 (t=0.115):	total squared error = 0.0206502, marker error: RMS=0.0230107, max=0.0454388 (L.Wrist)
# Frame 24 (t=0.12):	total squared error = 0.0210576, marker error: RMS=0.0232366, max=0.043974 (L.Bicep)
# Frame 25 (t=0.125):	total squared error = 0.0222376, marker error: RMS=0.0238788, max=0.0496077 (L.Wrist)
# Frame 26 (t=0.13):	total squared error = 0.0209621, marker error: RMS=0.0231838, max=0.0437389 (L.Shoulder)
# Frame 27 (t=0.135):	total squared error = 0.0216231, marker error: RMS=0.0235465, max=0.045269 (R.Heel)
# Frame 28 (t=0.14):	total squared error = 0.0224323, marker error: RMS=0.0239831, max=0.0471107 (R.Heel)
# Frame 29 (t=0.145):	total squared error = 0.0108473, marker error: RMS=0.0166774, max=0.0387031 (L.Bicep)
# Frame 30 (t=0.15):	total squared error = 0.00991869, marker error: RMS=0.0159476, max=0.0371469 (L.Bicep)
# Frame 31 (t=0.155):	total squared error = 0.00936032, marker error: RMS=0.0154922, max=0.0374237 (L.Bicep)
# Frame 32 (t=0.16):	total squared error = 0.00945344, marker error: RMS=0.0155691, max=0.0373776 (L.Bicep)
# Frame 33 (t=0.165):	total squared error = 0.00930639, marker error: RMS=0.0154475, max=0.0379853 (L.Bicep)
# Frame 34 (t=0.17):	total squared error = 0.00955496, marker error: RMS=0.0156524, max=0.0385447 (L.Wrist)
# Frame 35 (t=0.175):	total squared error = 0.00985293, marker error: RMS=0.0158946, max=0.0427132 (L.Wrist)
# Frame 36 (t=0.18):	total squared error = 0.0102044, marker error: RMS=0.0161757, max=0.045808 (L.Wrist)
# Frame 37 (t=0.185):	total squared error = 0.0104962, marker error: RMS=0.0164053, max=0.0484425 (L.Wrist)
# Frame 38 (t=0.19):	total squared error = 0.0112473, marker error: RMS=0.0169821, max=0.0515084 (L.Wrist)
# Frame 39 (t=0.195):	total squared error = 0.0111604, marker error: RMS=0.0169164, max=0.0543508 (L.Wrist)
# Frame 40 (t=0.2):	total squared error = 0.0112488, marker error: RMS=0.0169832, max=0.0549489 (L.Wrist)
# Frame 41 (t=0.205):	total squared error = 0.00940665, marker error: RMS=0.0155305, max=0.0363195 (L.Bicep)
# Frame 42 (t=0.21):	total squared error = 0.00939555, marker error: RMS=0.0155213, max=0.0354911 (L.Bicep)
# Frame 43 (t=0.215):	total squared error = 0.00986645, marker error: RMS=0.0159055, max=0.0366473 (L.Wrist)
# Frame 44 (t=0.22):	total squared error = 0.00966043, marker error: RMS=0.0157386, max=0.0406572 (L.Wrist)
# Frame 45 (t=0.225):	total squared error = 0.00961048, marker error: RMS=0.0156979, max=0.0377428 (L.Wrist)
# Frame 46 (t=0.23):	total squared error = 0.00975418, marker error: RMS=0.0158148, max=0.0406518 (L.Wrist)
# Frame 47 (t=0.235):	total squared error = 0.010118, marker error: RMS=0.016107, max=0.043003 (L.Wrist)
# Frame 48 (t=0.24):	total squared error = 0.00998993, marker error: RMS=0.0160048, max=0.0395125 (L.Wrist)
# Frame 49 (t=0.245):	total squared error = 0.0102823, marker error: RMS=0.0162373, max=0.041077 (L.Wrist)
# Frame 50 (t=0.25):	total squared error = 0.0108043, marker error: RMS=0.0166443, max=0.0430079 (L.Wrist)
# Frame 51 (t=0.255):	total squared error = 0.0108127, marker error: RMS=0.0166508, max=0.0398405 (L.Wrist)
# Frame 52 (t=0.26):	total squared error = 0.0112818, marker error: RMS=0.0170081, max=0.041632 (L.Wrist)
# Frame 53 (t=0.265):	total squared error = 0.0114666, marker error: RMS=0.0171469, max=0.0424411 (L.Wrist)
# Frame 54 (t=0.27):	total squared error = 0.0120283, marker error: RMS=0.0175619, max=0.0442116 (L.Wrist)
# Frame 55 (t=0.275):	total squared error = 0.0123048, marker error: RMS=0.0177625, max=0.0414092 (L.Wrist)
# Frame 56 (t=0.28):	total squared error = 0.0130779, marker error: RMS=0.018312, max=0.0436299 (L.Wrist)
# Frame 57 (t=0.285):	total squared error = 0.01357, marker error: RMS=0.0186534, max=0.0474998 (L.W

# %% [markdown]
# ### Setup COMAKTool

# %%
comak = osim.COMAKTool();
comak.set_model_file(model_file);
comak.set_coordinates_file(coordinates_file);
comak.set_external_loads_file(external_loads_file)
comak.set_results_directory(comak_result_dir);
comak.set_results_prefix(results_basename);
comak.set_replace_force_set(False);
comak.set_force_set_file(forceset_file));
comak.set_start_time(1.16);
comak.set_stop_time(2.32);
comak.set_time_step(0.01);
comak.set_lowpass_filter_frequency(6);
comak.set_print_processed_input_kinematics(True);

for coordinate_number, path in prescribed_coordinates.items():
    comak.set_prescribed_coordinates(int(coordinate_number), path)

for coord_number, path in primary_coordinates.items():
    comak.set_primary_coordinates(int(coord_number), path)
# Out:
# rist)
# Frame 58 (t=0.29):	total squared error = 0.014421, marker error: RMS=0.0192294, max=0.0485138 (L.Wrist)
# Frame 59 (t=0.295):	total squared error = 0.0157786, marker error: RMS=0.0201141, max=0.0500947 (L.Wrist)
# Frame 60 (t=0.3):	total squared error = 0.0144924, marker error: RMS=0.0192769, max=0.049095 (L.Wrist)
# Frame 61 (t=0.305):	total squared error = 0.0152092, marker error: RMS=0.0197479, max=0.0495633 (L.Wrist)
# Frame 62 (t=0.31):	total squared error = 0.0143865, marker error: RMS=0.0192063, max=0.0462431 (L.Wrist)
# Frame 63 (t=0.315):	total squared error = 0.0148388, marker error: RMS=0.019506, max=0.0461179 (L.Wrist)
# Frame 64 (t=0.32):	total squared error = 0.0153153, marker error: RMS=0.0198167, max=0.0420126 (L.Wrist)
# Frame 65 (t=0.325):	total squared error = 0.0164748, marker error: RMS=0.0205531, max=0.0437852 (L.Wrist)
# Frame 66 (t=0.33):	total squared error = 0.0138224, marker error: RMS=0.018826, max=0.0393298 (L.Wrist)
# Frame 67 (t=0.335):	total squared error = 0.014306, marker error: RMS=0.0191525, max=0.038102 (L.Wrist)
# Frame 68 (t=0.34):	total squared error = 0.0145021, marker error: RMS=0.0192834, max=0.0342138 (L.Wrist)
# Frame 69 (t=0.345):	total squared error = 0.0152887, marker error: RMS=0.0197994, max=0.0345934 (L.Wrist)
# Frame 70 (t=0.35):	total squared error = 0.0149646, marker error: RMS=0.0195885, max=0.0388773 (L.Wrist)
# Frame 71 (t=0.355):	total squared error = 0.0151834, marker error: RMS=0.0197311, max=0.0339863 (L.Wrist)
# Frame 72 (t=0.36):	total squared error = 0.0155715, marker error: RMS=0.0199818, max=0.0345646 (L.Wrist)
# Frame 73 (t=0.365):	total squared error = 0.015207, marker error: RMS=0.0197465, max=0.0354359 (L.Wrist)
# Frame 74 (t=0.37):	total squared error = 0.0155009, marker error: RMS=0.0199364, max=0.0325472 (L.Wrist)
# Frame 75 (t=0.375):	total squared error = 0.015587, marker error: RMS=0.0199917, max=0.0314885 (L.Bicep)
# Frame 76 (t=0.38):	total squared error = 0.015272, marker error: RMS=0.0197886, max=0.032037 (L.Bicep)
# Frame 77 (t=0.385):	total squared error = 0.0155468, marker error: RMS=0.0199659, max=0.0321691 (L.Bicep)
# Frame 78 (t=0.39):	total squared error = 0.0155032, marker error: RMS=0.0199378, max=0.0332667 (L.Bicep)
# Frame 79 (t=0.395):	total squared error = 0.0151952, marker error: RMS=0.0197388, max=0.0326782 (L.Bicep)
# Frame 80 (t=0.4):	total squared error = 0.015441, marker error: RMS=0.0198978, max=0.0331858 (L.Bicep)
# Frame 81 (t=0.405):	total squared error = 0.016291, marker error: RMS=0.0204381, max=0.0336528 (L.Bicep)
# Frame 82 (t=0.41):	total squared error = 0.0154838, marker error: RMS=0.0199254, max=0.0349071 (L.Bicep)
# Frame 83 (t=0.415):	total squared error = 0.0148522, marker error: RMS=0.0195148, max=0.0335619 (L.Bicep)
# Frame 84 (t=0.42):	total squared error = 0.0150742, marker error: RMS=0.0196601, max=0.0343492 (L.Bicep)
# Frame 85 (t=0.425):	total squared error = 0.0148245, marker error: RMS=0.0194965, max=0.0356047 (L.Bicep)
# Frame 86 (t=0.43):	total squared error = 0.0142396, marker error: RMS=0.0191081, max=0.0351088 (L.Bicep)
# Frame 87 (t=0.435):	total squared error = 0.0142514, marker error: RMS=0.019116, max=0.0360816 (L.Bicep)
# Frame 88 (t=0.44):	total squared error = 0.0137178, marker error: RMS=0.0187547, max=0.0361155 (L.Bicep)
# Frame 89 (t=0.445):	total squared error = 0.0138986, marker error: RMS=0.0188779, max=0.036458 (L.Bicep)
# Frame 90 (t=0.45):	total squared error = 0.0132493, marker error: RMS=0.0184316, max=0.0367696 (L.Bicep)
# Frame 91 (t=0.455):	total squared error = 0.0132852, marker error: RMS=0.0184566, max=0.0366993 (L.Bicep)
# Frame 92 (t=0.46):	total squared error = 0.0138087, marker error: RMS=0.0188168, max=0.0368216 (L.Bicep)
# Frame 93 (t=0.465):	total squared error = 0.0128282, marker error: RMS=0.0181364, max=0.0366647 (L.Bicep)
# Frame 94 (t=0.47):	total squared error = 0.0129625, marker error: RMS=0.0182311, max=0.0366138 (L.Bicep)
# Frame 95 (t=0.475):	total squared error = 0.013003, marker error: RMS=0.0182595, max=0.0374354 (L.Bicep)
# Frame 96 (t=0.48):	total squared error = 0.0126424, marker error: RMS=0.0180045, max=0.0369335 (L.Bicep)
# Frame 97 (t=0.485):	total squared error = 0.0126225, marker error: RMS=0.0179904, max=0.0365195 (L.Bicep)
# Frame 98 (t=0.49):	total squared error = 0.013161, marker error: RMS=0.0183701, max=0.036278 (L.Bicep)
# Frame 99 (t=0.495):	total squared error = 0.0121554, marker error: RMS=0.0176544, max=0.0362545 (L.Bicep)
# Frame 100 (t=0.5):	total squared error = 0.0122997, marker error: RMS=0.0177588, max=0.0355965 (L.Bicep)
# Frame 101 (t=0.505):	total squared error = 0.012595, marker error: RMS=0.0179708, max=0.0360749 (L.Bicep)
# Frame 102 (t=0.51):	total squared error = 0.0132135, marker error: RMS=0.0184067, max=0.0356181 (L.Bicep)
# Frame 103 (t=0.515):	total squared error = 0.0132989, marker error: RMS=0.0184661, max=0.0353679 (L.Bicep)
# Frame 104 (t=0.52):	total squared error = 0.0140249, marker error: RMS=0.0189635, max=0.0367896 (L.Wrist)
# Frame 105 (t=0.525):	total squared error = 0.012748, marker error: RMS=0.0180796, max=0.0353168 (L.Bicep)
# Frame 106 (t=0.53):	total squared error = 0.0111033, marker error: RMS=0.016873, max=0.0395145 (L.Bicep)
# Frame 107 (t=0.535):	total squared error = 0.0113312, marker error: RMS=0.0170453, max=0.0385152 (L.Bicep)
# Frame 108 (t=0.54):	total squared error = 0.0116218, marker error: RMS=0.0172625, max=0.0376593 (L.Bicep)
# Frame 109 (t=0.545):	total squared error = 0.0123285, marker error: RMS=0.0177796, max=0.0367868 (L.Bicep)
# Frame 110 (t=0.55):	total squared error = 0.011864, marker error: RMS=0.0174415, max=0.0332935 (L.Bicep)
# Frame 111 (t=0.555):	total squared error = 0.0122692, marker error: RMS=0.0177368, max=0.0341751 (L.Bicep)
# Frame 112 (t=0.56):	total squared error = 0.01255, marker error: RMS=0.0179387, max=0.0335933 (L.Bicep)
# Frame 113 (t=0.565):	total squared error = 0.0131791, marker error: RMS=0.0183827, max=0.0330446 (L.Bicep)
# Frame 114 (t=0.57):	total squared error = 0.0126046, marker error: RMS=0.0179776, max=0.0332704 (L.TH3)
# Frame 115 (t=0.575):	total squared error = 0.0129723, marker error: RMS=0.018238, max=0.0336872 (L.TH3)
# Frame 116 (t=0.58):	total squared error = 0.013791, marker error: RMS=0.0188047, max=0.0326219 (L.TH3)
# Frame 117 (t=0.585):	total squared error = 0.0130988, marker error: RMS=0.0183267, max=0.0352052 (L.TH3)
# Frame 118 (t=0.59):	total squared error = 0.0124272, marker error: RMS=0.0178506, max=0.0352624 (L.TH3)
# Frame 119 (t=0.595):	total squared error = 0.0126332, marker error: RMS=0.017998, max=0.0342352 (L.TH3)
# Frame 120 (t=0.6):	total squared error = 0.0128647, marker error: RMS=0.0181622, max=0.0357456 (L.TH3)
# Frame 121 (t=0.605):	total squared error = 0.0128555, marker error: RMS=0.0181557, max=0.0368414 (L.TH3)
# Frame 122 (t=0.61):	total squared error = 0.0131345, marker error: RMS=0.0183517, max=0.0350173 (L.TH3)
# Frame 123 (t=0.615):	total squared error = 0.0125292, marker error: RMS=0.0179238, max=0.0358726 (L.TH3)
# Frame 124 (t=0.62):	total squared error = 0.0125469, marker error: RMS=0.0179364, max=0.0355249 (L.TH3)
# Frame 125 (t=0.625):	total squared error = 0.0124694, marker error: RMS=0.017881, max=0.0359111 (L.TH3)
# Frame 126 (t=0.63):	total squared error = 0.0117801, marker error: RMS=0.0173797, max=0.0342845 (L.TH3)
# Frame 127 (t=0.635):	total squared error = 0.01178, marker error: RMS=0.0173796, max=0.0322727 (L.TH3)
# Frame 128 (t=0.64):	total squared error = 0.0119622, marker error: RMS=0.0175135, max=0.0322151 (L.TH3)
# Frame 129 (t=0.645):	total squared error = 0.0112183, marker error: RMS=0.0169602, max=0.0315374 (L.TH3)
# Frame 130 (t=0.65):	total squared error = 0.0106548, marker error: RMS=0.0165287, max=0.0314965 (L.Bicep)
# Frame 131 (t=0.655):	total squared error = 0.0106321, marker error: RMS=0.0165112, max=0.030576 (L.Bicep)
# Frame 132 (t=0.66):	total squared error = 0.0105325, marker error: RMS=0.0164337, max=0.0301636 (R.Bicep)
# Frame 133 (t=0.665):	total squared error = 0.0107469, marker error: RMS=0.0166001, max=0.031106 (R.Bicep)
# Frame 134 (t=0.67):	total squared error = 0.0107392, marker error: RMS=0.0165941, max=0.0322506 (R.Bicep)
# Frame 135 (t=0.675):	total squared error = 0.0101599, marker error: RMS=0.0161403, max=0.0297634 (R.Bicep)
# Frame 136 (t=0.68):	total squared error = 0.0102367, marker error: RMS=0.0162012, max=0.0301197 (R.Bicep)
# Frame 137 (t=0.685):	total squared error = 0.0102055, marker error: RMS=0.0161765, max=0.0316242 (R.Bicep)
# Frame 138 (t=0.69):	total squared error = 0.0103667, marker error: RMS=0.0163038, max=0.0317098 (R.Bicep)
# Frame 139 (t=0.695):	total squared error = 0.0107497, marker error: RMS=0.0166022, max=0.0319777 (R.Bicep)
# Frame 140 (t=0.7):	total squared error = 0.0104134, marker error: RMS=0.0163405, max=0.0324443 (R.Bicep)
# Frame 141 (t=0.705):	total squared error = 0.0104081, marker error: RMS=0.0163363, max=0.0320007 (R.Bicep)
# Frame 142 (t=0.71):	total squared error = 0.00975038, marker error: RMS=0.0158117, max=0.0327188 (L.Bicep)
# Frame 143 (t=0.715):	total squared error = 0.00959347, marker error: RMS=0.015684, max=0.0324117 (L.Bicep)
# Frame 144 (t=0.72):	total squared error = 0.0095498, marker error: RMS=0.0156482, max=0.0318495 (L.Bicep)
# Frame 145 (t=0.725):	total squared error = 0.00957426, marker error: RMS=0.0156682, max=0.0315169 (L.Bicep)
# Frame 146 (t=0.73):	total squared error = 0.0097158, marker error: RMS=0.0157836, max=0.0305423 (L.Bicep)
# Frame 147 (t=0.735):	total squared error = 0.00939656, marker error: RMS=0.0155222, max=0.0346068 (L.Bicep)
# Frame 148 (t=0.74):	total squared error = 0.00941647, marker error: RMS=0.0155386, max=0.0329278 (L.Bicep)
# Frame 149 (t=0.745):	total squared error = 0.00954025, marker error: RMS=0.0156404, max=0.033028 (L.Bicep)
# Frame 150 (t=0.75):	total squared error = 0.00949189, marker error: RMS=0.0156007, max=0.0347487 (L.Bicep)
# Frame 151 (t=0.755):	total squared error = 0.00959481, marker error: RMS=0.0156851, max=0.0339104 (L.Bicep)
# Frame 152 (t=0.76):	total squared error = 0.00991575, marker error: RMS=0.0159452, max=0.0333077 (L.Bicep)
# Frame 153 (t=0.765):	total squared error = 0.0100183, marker error: RMS=0.0160275, max=0.0366441 (L.Bicep)
# Frame 154 (t=0.77):	total squared error = 0.0102321, marker error: RMS=0.0161976, max=0.0358295 (L.Bicep)
# Frame 155 (t=0.775):	total squared error = 0.0102466, marker error: RMS=0.0162091, max=0.0358348 (L.Bicep)
# Frame 156 (t=0.78):	total squared error = 0.0105208, marker error: RMS=0.0164245, max=0.0350804 (L.Bicep)
# Frame 157 (t=0.785):	total squared error = 0.0104764, marker error: RMS=0.0163898, max=0.0341662 (L.Bicep)
# Frame 158 (t=0.79):	total squared error = 0.0108988, marker error: RMS=0.016717, max=0.0335146 (L.Bicep)
# Frame 159 (t=0.795):	total squared error = 0.0116728, marker error: RMS=0.0173003, max=0.033177 (L.Bicep)
# Frame 160 (t=0.8):	total squared error = 0.0120876, marker error: RMS=0.017605, max=0.0354461 (L.Bicep)
# Frame 161 (t=0.805):	total squared error = 0.0119704, marker error: RMS=0.0175195, max=0.0335498 (L.Bicep)
# Frame 162 (t=0.81):	total squared error = 0.012554, marker error: RMS=0.0179415, max=0.032915 (L.Bicep)
# Frame 163 (t=0.815):	total squared error = 0.0131562, marker error: RMS=0.0183668, max=0.0355204 (L.Bicep)
# Frame 164 (t=0.82):	total squared error = 0.0140532, marker error: RMS=0.0189826, max=0.0351182 (R.Knee)
# Frame 165 (t=0.825):	total squared error = 0.0154373, marker error: RMS=0.0198954, max=0.0383626 (R.Knee)
# Frame 166 (t=0.83):	total squared error = 0.0160933, marker error: RMS=0.0203138, max=0.039962 (R.Knee)
# Frame 167 (t=0.835):	total squared error = 0.0114572, marker error: RMS=0.0171398, max=0.038094 (R.Heel)
# Frame 168 (t=0.84):	total squared error = 0.0107611, marker error: RMS=0.016611, max=0.0340137 (R.Heel)
# Frame 169 (t=0.845):	total squared error = 0.0102163, marker error: RMS=0.016185, max=0.0319951 (L.Bicep)
# Frame 170 (t=0.85):	total squared error = 0.00997629, marker error: RMS=0.0159938, max=0.032565 (L.Bicep)
# Frame 171 (t=0.855):	total squared error = 0.00976623, marker error: RMS=0.0158245, max=0.0333001 (L.Bicep)
# Frame 172 (t=0.86):	total squared error = 0.0095938, marker error: RMS=0.0156842, max=0.0323981 (L.Bicep)
# Frame 173 (t=0.865):	total squared error = 0.00944863, marker error: RMS=0.0155651, max=0.0337587 (L.Bicep)
# Frame 174 (t=0.87):	total squared error = 0.00934124, marker error: RMS=0.0154764, max=0.0325188 (L.Bicep)
# Frame 175 (t=0.875):	total squared error = 0.00929487, marker error: RMS=0.0154379, max=0.0342083 (L.Bicep)
# Frame 176 (t=0.88):	total squared error = 0.0092337, marker error: RMS=0.0153871, max=0.0328177 (L.Bicep)
# Frame 177 (t=0.885):	total squared error = 0.00918475, marker error: RMS=0.0153462, max=0.0345136 (L.Bicep)
# Frame 178 (t=0.89):	total squared error = 0.00914809, marker error: RMS=0.0153156, max=0.033015 (L.Bicep)
# Frame 179 (t=0.895):	total squared error = 0.00879848, marker error: RMS=0.0150201, max=0.0334914 (L.Bicep)
# Frame 180 (t=0.9):	total squared error = 0.00877696, marker error: RMS=0.0150017, max=0.0334201 (L.Bicep)
# Frame 181 (t=0.905):	total squared error = 0.00884205, marker error: RMS=0.0150572, max=0.0341825 (L.Bicep)
# Frame 182 (t=0.91):	total squared error = 0.00906257, marker error: RMS=0.0152438, max=0.0334099 (L.Bicep)
# Frame 183 (t=0.915):	total squared error = 0.00902592, marker error: RMS=0.0152129, max=0.0351349 (R.Bicep)
# Frame 184 (t=0.92):	total squared error = 0.00848895, marker error: RMS=0.0147535, max=0.0331164 (L.Bicep)
# Frame 185 (t=0.925):	total squared error = 0.00835033, marker error: RMS=0.0146325, max=0.0334515 (L.Bicep)
# Frame 186 (t=0.93):	total squared error = 0.00858947, marker error: RMS=0.0148406, max=0.0332542 (L.Bicep)
# Frame 187 (t=0.935):	total squared error = 0.0085064, marker error: RMS=0.0147686, max=0.0353625 (R.Bicep)
# Frame 188 (t=0.94):	total squared error = 0.00856053, marker error: RMS=0.0148156, max=0.0338978 (R.Bicep)
# Frame 189 (t=0.945):	total squared error = 0.0084287, marker error: RMS=0.014701, max=0.0355976 (R.Bicep)
# Frame 190 (t=0.95):	total squared error =
#   File "/tmp/ipykernel_3304/2091335479.py", line 8
#     comak.set_force_set_file(forceset_file));
#                                            ^
# SyntaxError: invalid syntax
# 0.00826639, marker error: RMS=0.0145588, max=0.0344481 (R.Bicep)
# Frame 191 (t=0.955):	total squared error = 0.00822895, marker error: RMS=0.0145258, max=0.0340729 (R.Bicep)
# Frame 192 (t=0.96):	total squared error = 0.00818465, marker error: RMS=0.0144866, max=0.0353601 (R.Bicep)
# Frame 193 (t=0.965):	total squared error = 0.00828951, marker error: RMS=0.0145792, max=0.0343284 (R.Bicep)
# Frame 194 (t=0.97):	total squared error = 0.00828484, marker error: RMS=0.014575, max=0.0355192 (R.Bicep)
# Frame 195 (t=0.975):	total squared error = 0.00839495, marker error: RMS=0.0146716, max=0.0344114 (R.Bicep)
# Frame 196 (t=0.98):	total squared error = 0.0091518, marker error: RMS=0.0153187, max=0.0339403 (R.Bicep)
# Frame 197 (t=0.985):	total squared error = 0.00818325, marker error: RMS=0.0144854, max=0.0341995 (R.Bicep)
# Frame 198 (t=0.99):	total squared error = 0.00825876, marker error: RMS=0.0145521, max=0.0344644 (R.Bicep)
# Frame 199 (t=0.995):	total squared error = 0.00878727, marker error: RMS=0.0150105, max=0.0338099 (R.Bicep)
# Frame 200 (t=1):	total squared error = 0.00985349, marker error: RMS=0.0158951, max=0.0355216 (L.Wrist)
# Frame 201 (t=1.005):	total squared error = 0.00845778, marker error: RMS=0.0147264, max=0.0335132 (R.Bicep)
# Frame 202 (t=1.01):	total squared error = 0.00881342, marker error: RMS=0.0150328, max=0.0330578 (R.Bicep)
# Frame 203 (t=1.015):	total squared error = 0.00906382, marker error: RMS=0.0152449, max=0.034637 (R.Bicep)
# Frame 204 (t=1.02):	total squared error = 0.00992346, marker error: RMS=0.0159514, max=0.0344375 (R.Bicep)
# Frame 205 (t=1.025):	total squared error = 0.00844811, marker error: RMS=0.014718, max=0.0352057 (R.Bicep)
# Frame 206 (t=1.03):	total squared error = 0.00880301, marker error: RMS=0.0150239, max=0.0345597 (R.Bicep)
# Frame 207 (t=1.035):	total squared error = 0.0088434, marker error: RMS=0.0150583, max=0.0345633 (R.Bicep)
# Frame 208 (t=1.04):	total squared error = 0.00887943, marker error: RMS=0.015089, max=0.0329525 (R.Bicep)
# Frame 209 (t=1.045):	total squared error = 0.00964664, marker error: RMS=0.0157274, max=0.0328253 (R.Bicep)
# Frame 210 (t=1.05):	total squared error = 0.00994802, marker error: RMS=0.0159711, max=0.0344984 (R.Bicep)
# Frame 211 (t=1.055):	total squared error = 0.0110863, marker error: RMS=0.0168601, max=0.0344049 (R.Bicep)
# Frame 212 (t=1.06):	total squared error = 0.0107981, marker error: RMS=0.0166395, max=0.0345722 (R.Bicep)
# Frame 213 (t=1.065):	total squared error = 0.0118022, marker error: RMS=0.017396, max=0.0344168 (R.Bicep)
# Frame 214 (t=1.07):	total squared error = 0.0106055, marker error: RMS=0.0164904, max=0.0361271 (R.Bicep)
# Frame 215 (t=1.075):	total squared error = 0.0113411, marker error: RMS=0.0170528, max=0.0355704 (R.Bicep)
# Frame 216 (t=1.08):	total squared error = 0.0111003, marker error: RMS=0.0168708, max=0.032482 (R.Bicep)
# Frame 217 (t=1.085):	total squared error = 0.0122569, marker error: RMS=0.017728, max=0.032461 (R.Bicep)
# Frame 218 (t=1.09):	total squared error = 0.0118809, marker error: RMS=0.0174539, max=0.0319595 (R.Bicep)
# Frame 219 (t=1.095):	total squared error = 0.0129913, marker error: RMS=0.0182513, max=0.0319742 (R.Bicep)
# Frame 220 (t=1.1):	total squared error = 0.0135723, marker error: RMS=0.018655, max=0.0339684 (L.Bicep)
# Frame 221 (t=1.105):	total squared error = 0.0132086, marker error: RMS=0.0184033, max=0.0321554 (L.Bicep)
# Frame 222 (t=1.11):	total squared error = 0.0139756, marker error: RMS=0.0189301, max=0.033584 (L.Bicep)
# Frame 223 (t=1.115):	total squared error = 0.0138015, marker error: RMS=0.0188119, max=0.0328779 (L.Bicep)
# Frame 224 (t=1.12):	total squared error = 0.0140204, marker error: RMS=0.0189604, max=0.0326102 (L.Bicep)
# Frame 225 (t=1.125):	total squared error = 0.0139953, marker error: RMS=0.0189434, max=0.0320142 (L.Bicep)
# Frame 226 (t=1.13):	total squared error = 0.0140536, marker error: RMS=0.0189828, max=0.0307264 (L.Bicep)
# Frame 227 (t=1.135):	total squared error = 0.0145521, marker error: RMS=0.0193166, max=0.0335237 (L.Bicep)
# Frame 228 (t=1.14):	total squared error = 0.0148954, marker error: RMS=0.0195431, max=0.0349555 (L.Bicep)
# Frame 229 (t=1.145):	total squared error = 0.014891, marker error: RMS=0.0195402, max=0.034739 (L.Bicep)
# Frame 230 (t=1.15):	total squared error = 0.0145672, marker error: RMS=0.0193266, max=0.0329769 (L.Bicep)
# Frame 231 (t=1.155):	total squared error = 0.0150375, marker error: RMS=0.0196361, max=0.0351312 (L.Bicep)
# Frame 232 (t=1.16):	total squared error = 0.0155448, marker error: RMS=0.0199646, max=0.0371683 (L.Bicep)
# Frame 233 (t=1.165):	total squared error = 0.0159475, marker error: RMS=0.0202216, max=0.0392531 (R.Heel)
# Frame 234 (t=1.17):	total squared error = 0.016963, marker error: RMS=0.0208554, max=0.0430946 (R.Heel)
# Frame 235 (t=1.175):	total squared error = 0.0183583, marker error: RMS=0.0216962, max=0.0461844 (R.Heel)
# Frame 236 (t=1.18):	total squared error = 0.018031, marker error: RMS=0.0215019, max=0.0455324 (R.Heel)
# Frame 237 (t=1.185):	total squared error = 0.0191364, marker error: RMS=0.0221512, max=0.0488602 (R.Heel)
# Frame 238 (t=1.19):	total squared error = 0.0204986, marker error: RMS=0.0229261, max=0.0511567 (R.Heel)
# Frame 239 (t=1.195):	total squared error = 0.00842988, marker error: RMS=0.0147021, max=0.0322662 (L.Bicep)
# Frame 240 (t=1.2):	total squared error = 0.0074038, marker error: RMS=0.0137783, max=0.0325179 (L.Bicep)
# Frame 241 (t=1.205):	total squared error = 0.00702556, marker error: RMS=0.0134217, max=0.0329018 (L.Bicep)
# Frame 242 (t=1.21):	total squared error = 0.00695271, marker error: RMS=0.013352, max=0.0333911 (L.Bicep)
# Frame 243 (t=1.215):	total squared error = 0.00698779, marker error: RMS=0.0133856, max=0.0337769 (L.Bicep)
# Frame 244 (t=1.22):	total squared error = 0.00706575, marker error: RMS=0.0134601, max=0.0345701 (L.Bicep)
# Frame 245 (t=1.225):	total squared error = 0.00722148, marker error: RMS=0.0136076, max=0.0347849 (L.Bicep)
# Frame 246 (t=1.23):	total squared error = 0.00677016, marker error: RMS=0.0131755, max=0.0368512 (L.Bicep)
# Frame 247 (t=1.235):	total squared error = 0.00715014, marker error: RMS=0.0135402, max=0.0367549 (L.Bicep)
# Frame 248 (t=1.24):	total squared error = 0.00685118, marker error: RMS=0.0132541, max=0.0361621 (L.Bicep)
# Frame 249 (t=1.245):	total squared error = 0.00691566, marker error: RMS=0.0133163, max=0.0360245 (L.Bicep)
# Frame 250 (t=1.25):	total squared error = 0.00733656, marker error: RMS=0.0137156, max=0.035701 (L.Bicep)
# Frame 251 (t=1.255):	total squared error = 0.00645005, marker error: RMS=0.0128602, max=0.0356326 (L.Bicep)
# Frame 252 (t=1.26):	total squared error = 0.00636973, marker error: RMS=0.0127799, max=0.0345794 (L.Bicep)
# Frame 253 (t=1.265):	total squared error = 0.00642047, marker error: RMS=0.0128307, max=0.0336121 (L.Bicep)
# Frame 254 (t=1.27):	total squared error = 0.00687352, marker error: RMS=0.0132757, max=0.0329873 (L.Bicep)
# Frame 255 (t=1.275):	total squared error = 0.00629726, marker error: RMS=0.012707, max=0.0319557 (L.Bicep)
# Frame 256 (t=1.28):	total squared error = 0.00633267, marker error: RMS=0.0127427, max=0.030507 (L.Bicep)
# Frame 257 (t=1.285):	total squared error = 0.00630391, marker error: RMS=0.0127137, max=0.0299697 (L.Bicep)
# Frame 258 (t=1.29):	total squared error = 0.00639988, marker error: RMS=0.0128101, max=0.0278556 (L.Bicep)
# Frame 259 (t=1.295):	total squared error = 0.00654902, marker error: RMS=0.0129585, max=0.0275508 (L.Bicep)
# Frame 260 (t=1.3):	total squared error = 0.00680515, marker error: RMS=0.0132095, max=0.025958 (L.Bicep)
# Frame 261 (t=1.305):	total squared error = 0.0073307, marker error: RMS=0.0137101, max=0.0244025 (L.Bicep)
# Frame 262 (t=1.31):	total squared error = 0.00817921, marker error: RMS=0.0144818, max=0.025246 (R.MT5)
# Frame 263 (t=1.315):	total squared error = 0.0082789, marker error: RMS=0.0145698, max=0.0282212 (R.MT5)
# Frame 264 (t=1.32):	total squared error = 0.00883744, marker error: RMS=0.0150533, max=0.0300354 (R.MT5)
# Frame 265 (t=1.325):	total squared error = 0.00979116, marker error: RMS=0.0158447, max=0.032012 (R.MT5)
# Frame 266 (t=1.33):	total squared error = 0.00989846, marker error: RMS=0.0159313, max=0.0341511 (R.MT5)
# Frame 267 (t=1.335):	total squared error = 0.0105445, marker error: RMS=0.016443, max=0.0356659 (R.MT5)
# Frame 268 (t=1.34):	total squared error = 0.010225, marker error: RMS=0.016192, max=0.0363665 (R.MT5)
# Frame 269 (t=1.345):	total squared error = 0.00972984, marker error: RMS=0.015795, max=0.032742 (R.MT5)
# Frame 270 (t=1.35):	total squared error = 0.0102989, marker error: RMS=0.0162504, max=0.0339444 (R.MT5)
# Frame 271 (t=1.355):	total squared error = 0.0105362, marker error: RMS=0.0164365, max=0.0352074 (R.MT5)
# Frame 272 (t=1.36):	total squared error = 0.0110402, marker error: RMS=0.016825, max=0.0348893 (R.MT5)
# Frame 273 (t=1.365):	total squared error = 0.0108679, marker error: RMS=0.0166932, max=0.0334263 (R.MT5)
# Frame 274 (t=1.37):	total squared error = 0.0112495, marker error: RMS=0.0169838, max=0.0340478 (R.MT5)
# Frame 275 (t=1.375):	total squared error = 0.0117726, marker error: RMS=0.0173741, max=0.0337306 (R.MT5)
# Frame 276 (t=1.38):	total squared error = 0.0126914, marker error: RMS=0.0180394, max=0.0338612 (R.MT5)
# Frame 277 (t=1.385):	total squared error = 0.0129708, marker error: RMS=0.0182369, max=0.0325961 (R.MT5)
# Frame 278 (t=1.39):	total squared error = 0.0135236, marker error: RMS=0.0186215, max=0.0322837 (R.MT5)
# Frame 279 (t=1.395):	total squared error = 0.0130334, marker error: RMS=0.0182809, max=0.0322718 (R.MT5)
# Frame 280 (t=1.4):	total squared error = 0.0137815, marker error: RMS=0.0187982, max=0.0312506 (R.MT5)
# Frame 281 (t=1.405):	total squared error = 0.0129682, marker error: RMS=0.0182351, max=0.0296926 (R.MT5)
# Frame 282 (t=1.41):	total squared error = 0.0130733, marker error: RMS=0.0183088, max=0.0293158 (R.SH3)
# Frame 283 (t=1.415):	total squared error = 0.0132904, marker error: RMS=0.0184602, max=0.028929 (L.TH4)
# Frame 284 (t=1.42):	total squared error = 0.0133133, marker error: RMS=0.0184761, max=0.0294497 (R.Knee)
# Frame 285 (t=1.425):	total squared error = 0.0130503, marker error: RMS=0.0182927, max=0.0292423 (R.Knee)
# Frame 286 (t=1.43):	total squared error = 0.0131518, marker error: RMS=0.0183637, max=0.0284311 (R.SH3)
# Frame 287 (t=1.435):	total squared error = 0.0130223, marker error: RMS=0.0182731, max=0.02827 (R.Knee)
# Frame 288 (t=1.44):	total squared error = 0.0133081, marker error: RMS=0.0184725, max=0.0289202 (L.TH4)
# Frame 289 (t=1.445):	total squared error = 0.012937, marker error: RMS=0.0182131, max=0.0276634 (L.Bicep)
# Frame 290 (t=1.45):	total squared error = 0.0130655, marker error: RMS=0.0183034, max=0.0289923 (L.TH4)
# Frame 291 (t=1.455):	total squared error = 0.0126861, marker error: RMS=0.0180356, max=0.0309115 (L.Bicep)
# Frame 292 (t=1.46):	total squared error = 0.0122903, marker error: RMS=0.0177521, max=0.0306782 (L.Bicep)
# Frame 293 (t=1.465):	total squared error = 0.0124681, marker error: RMS=0.01788, max=0.0311992 (L.Bicep)
# Frame 294 (t=1.47):	total squared error = 0.0120631, marker error: RMS=0.0175872, max=0.0309684 (L.Bicep)
# Frame 295 (t=1.475):	total squared error = 0.0122767, marker error: RMS=0.0177422, max=0.031456 (L.Bicep)
# Frame 296 (t=1.48):	total squared error = 0.0120177, marker error: RMS=0.0175541, max=0.0314424 (L.Bicep)
# Frame 297 (t=1.485):	total squared error = 0.0121337, marker error: RMS=0.0176386, max=0.0316778 (L.Bicep)
# Frame 298 (t=1.49):	total squared error = 0.0127859, marker error: RMS=0.0181064, max=0.0318817 (L.Bicep)
# Frame 299 (t=1.495):	total squared error = 0.0120901, marker error: RMS=0.0176069, max=0.031096 (L.Bicep)
# Frame 300 (t=1.5):	total squared error = 0.0124029, marker error: RMS=0.0178332, max=0.0313896 (L.Bicep)
# Frame 301 (t=1.505):	total squared error = 0.0118831, marker error: RMS=0.0174555, max=0.0314487 (L.Bicep)
# Frame 302 (t=1.51):	total squared error = 0.0119126, marker error: RMS=0.0174771, max=0.0315331 (L.Bicep)
# Frame 303 (t=1.515):	total squared error = 0.0112301, marker error: RMS=0.0169691, max=0.0326044 (L.Bicep)
# Frame 304 (t=1.52):	total squared error = 0.0111927, marker error: RMS=0.0169408, max=0.0325039 (L.Bicep)
# Frame 305 (t=1.525):	total squared error = 0.0115661, marker error: RMS=0.0172211, max=0.0323581 (L.Bicep)
# Frame 306 (t=1.53):	total squared error = 0.0116407, marker error: RMS=0.0172766, max=0.0317807 (L.Bicep)
# Frame 307 (t=1.535):	total squared error = 0.0113999, marker error: RMS=0.017097, max=0.0309548 (L.Bicep)
# Frame 308 (t=1.54):	total squared error = 0.0116021, marker error: RMS=0.0172479, max=0.030876 (L.Bicep)
# Frame 309 (t=1.545):	total squared error = 0.0123168, marker error: RMS=0.0177712, max=0.0355659 (L.Wrist)
# Frame 310 (t=1.55):	total squared error = 0.0112396, marker error: RMS=0.0169763, max=0.0306141 (L.Bicep)
# Frame 311 (t=1.555):	total squared error = 0.0115025, marker error: RMS=0.0171737, max=0.0300032 (L.Bicep)
# Frame 312 (t=1.56):	total squared error = 0.011797, marker error: RMS=0.0173922, max=0.03027 (L.Bicep)
# Frame 313 (t=1.565):	total squared error = 0.0108355, marker error: RMS=0.0166684, max=0.0305444 (L.Bicep)
# Frame 314 (t=1.57):	total squared error = 0.0111644, marker error: RMS=0.0169194, max=0.0308098 (L.Bicep)
# Frame 315 (t=1.575):	total squared error = 0.0107597, marker error: RMS=0.0166099, max=0.0309035 (L.Bicep)
# Frame 316 (t=1.58):	total squared error = 0.0110734, marker error: RMS=0.0168503, max=0.0306634 (L.Bicep)
# Frame 317 (t=1.585):	total squared error = 0.0115198, marker error: RMS=0.0171866, max=0.0310774 (L.TH3)
# Frame 318 (t=1.59):	total squared error = 0.0116224, marker error: RMS=0.017263, max=0.0326164 (L.TH3)
# Frame 319 (t=1.595):	total squared error = 0.0121557, marker error: RMS=0.0176546, max=0.0320543 (L.TH3)
# Frame 320 (t=1.6):	total squared error = 0.0116746, marker error: RMS=0.0173017, max=0.0335794 (L.TH3)
# Frame 321 (t=1.605):	total squared error = 0.0110579, marker error: RMS=0.0168385, max=0.0339597 (L.TH3)
# Frame 322 (t=1.61):	total squared error = 0.0113527, marke

# %%
print(coordinate_number)

# %%
secondary_coord_set = osim.COMAKSecondaryCoordinateSet(); 
secondary_coord = osim.COMAKSecondaryCoordinate();

for coord, dict_ in secondary_coordinates.items():
    secondary_coord.setName(coord)
    secondary_coord.set_max_change(dict_['max_change']);
    secondary_coord.set_coordinate(dict_['coordinate']);
    secondary_coord_set.cloneAndAppend(secondary_coord);

comak.set_COMAKSecondaryCoordinateSet(secondary_coord_set);

# %%
comak.set_settle_secondary_coordinates_at_start(True);
comak.set_settle_threshold(1e-3);
comak.set_settle_accuracy(1e-2);
comak.set_settle_internal_step_limit(10000);
comak.set_print_settle_sim_results(True);
comak.set_settle_sim_results_directory(comak_result_dir);
comak.set_settle_sim_results_prefix('walking_settle_sim');
comak.set_max_iterations(25);
comak.set_udot_tolerance(1);
comak.set_udot_worse_case_tolerance(50);
comak.set_unit_udot_epsilon(1e-6);
comak.set_optimization_scale_delta_coord(1);
comak.set_ipopt_diagnostics_level(3);
comak.set_ipopt_max_iterations(500);
comak.set_ipopt_convergence_tolerance(1e-4);
comak.set_ipopt_constraint_tolerance(1e-4);
comak.set_ipopt_limited_memory_history(200);
comak.set_ipopt_nlp_scaling_max_gradient(10000);
comak.set_ipopt_nlp_scaling_min_value(1e-8);
comak.set_ipopt_obj_scaling_factor(1);
comak.set_activation_exponent(2);
comak.set_contact_energy_weight(0);
comak.set_non_muscle_actuator_weight(1000);
comak.set_model_assembly_accuracy(1e-12);
comak.set_use_visualizer(False);
# # comak.set_verbose(2);
comak.setDebugLevel(2)
comak.printToXML(save_xml_path);

# %%
print('Running COMAK Tool...')
comak.run();
print('Done!')

# %% [markdown]
# ### Perform Joint Mechanics Analysis

# %%
## Perform Joint Mechanics Analysis
jnt_mech = osim.JointMechanicsTool();
jnt_mech.set_model_file(model_file);
jnt_mech.set_input_states_file([os.path.join(comak_result_dir, results_basename + '_states.sto')]);
jnt_mech.set_use_muscle_physiology(False);
jnt_mech.set_results_file_basename(results_basename);
jnt_mech.set_results_directory(jnt_mech_result_dir);
jnt_mech.set_start_time(1.16);
jnt_mech.set_stop_time(-1);
jnt_mech.set_resample_step_size(-1);
jnt_mech.set_normalize_to_cycle(True);
jnt_mech.set_lowpass_filter_frequency(-1);
jnt_mech.set_print_processed_kinematics(False);
jnt_mech.set_contacts(0,'all');
jnt_mech.set_contact_outputs(0,'all');
jnt_mech.set_contact_mesh_properties(0,'none');
jnt_mech.set_ligaments(0,'all');
jnt_mech.set_ligament_outputs(0,'all');
jnt_mech.set_muscles(0,'all');
jnt_mech.set_muscle_outputs(0,'all');

jnt_mech.set_attached_geometry_bodies(0,'all');

jnt_mech.set_output_orientation_frame('ground');
jnt_mech.set_output_position_frame('ground');
jnt_mech.set_write_vtp_files(True);
jnt_mech.set_vtp_file_format('binary');
jnt_mech.set_write_h5_file(False);
jnt_mech.set_h5_kinematics_data(True);
jnt_mech.set_h5_states_data(True);
jnt_mech.set_write_transforms_file(False);
jnt_mech.set_output_transforms_file_type('sto');
jnt_mech.set_use_visualizer(False);
jnt_mech.set_verbose(0);

analysis_set = AnalysisSet();

frc_reporter = ForceReporter();
frc_reporter.setName('ForceReporter');

analysis_set.cloneAndAppend(frc_reporter);
jnt_mech.set_AnalysisSet(analysis_set);
jnt_mech.printToXML('./inputs/joint_mechanics_settings.xml');

print('Running JointMechanicsTool...');
jnt_mech.run();
# Out:
# r error: RMS=0.0170615, max=0.0333304 (L.TH3)
# Frame 323 (t=1.615):	total squared error = 0.0114566, marker error: RMS=0.0171394, max=0.0350878 (L.TH3)
# Frame 324 (t=1.62):	total squared error = 0.011839, marker error: RMS=0.0174231, max=0.0353306 (L.TH3)
# Frame 325 (t=1.625):	total squared error = 0.0119745, marker error: RMS=0.0175225, max=0.0368349 (L.TH3)
# Frame 326 (t=1.63):	total squared error = 0.0118209, marker error: RMS=0.0174098, max=0.0368162 (L.TH3)
# Frame 327 (t=1.635):	total squared error = 0.0121648, marker error: RMS=0.0176612, max=0.0353059 (L.TH3)
# Frame 328 (t=1.64):	total squared error = 0.0126148, marker error: RMS=0.0179849, max=0.0365106 (L.TH3)
# Frame 329 (t=1.645):	total squared error = 0.0122593, marker error: RMS=0.0177297, max=0.0368295 (L.TH3)
# Frame 330 (t=1.65):	total squared error = 0.012742, marker error: RMS=0.0180753, max=0.0352115 (L.TH3)
# Frame 331 (t=1.655):	total squared error = 0.0137974, marker error: RMS=0.018809, max=0.0333203 (L.TH3)
# Frame 332 (t=1.66):	total squared error = 0.0123563, marker error: RMS=0.0177997, max=0.0363075 (L.TH3)
# Frame 333 (t=1.665):	total squared error = 0.0115733, marker error: RMS=0.0172265, max=0.0342404 (L.Bicep)
# Frame 334 (t=1.67):	total squared error = 0.0116791, marker error: RMS=0.017305, max=0.0335267 (L.Bicep)
# Frame 335 (t=1.675):	total squared error = 0.0116952, marker error: RMS=0.017317, max=0.0328749 (L.TH3)
# Frame 336 (t=1.68):	total squared error = 0.0114479, marker error: RMS=0.0171329, max=0.033356 (L.TH3)
# Frame 337 (t=1.685):	total squared error = 0.0116778, marker error: RMS=0.0173041, max=0.0311308 (L.TH3)
# Frame 338 (t=1.69):	total squared error = 0.0107606, marker error: RMS=0.0166107, max=0.0322272 (L.Bicep)
# Frame 339 (t=1.695):	total squared error = 0.0107627, marker error: RMS=0.0166122, max=0.0319435 (L.Bicep)
# Frame 340 (t=1.7):	total squared error = 0.0102877, marker error: RMS=0.0162415, max=0.0320864 (L.Bicep)
# Frame 341 (t=1.705):	total squared error = 0.010326, marker error: RMS=0.0162717, max=0.0317588 (L.Bicep)
# Frame 342 (t=1.71):	total squared error = 0.0102815, marker error: RMS=0.0162367, max=0.0311417 (L.Bicep)
# Frame 343 (t=1.715):	total squared error = 0.0105077, marker error: RMS=0.0164143, max=0.0312405 (L.Bicep)
# Frame 344 (t=1.72):	total squared error = 0.0104022, marker error: RMS=0.0163316, max=0.0319323 (R.Bicep)
# Frame 345 (t=1.725):	total squared error = 0.00998905, marker error: RMS=0.016004, max=0.0320468 (L.Bicep)
# Frame 346 (t=1.73):	total squared error = 0.00977903, marker error: RMS=0.0158349, max=0.0318861 (L.Bicep)
# Frame 347 (t=1.735):	total squared error = 0.00994784, marker error: RMS=0.015971, max=0.0312056 (L.Bicep)
# Frame 348 (t=1.74):	total squared error = 0.0101728, marker error: RMS=0.0161506, max=0.0311787 (L.Bicep)
# Frame 349 (t=1.745):	total squared error = 0.00983186, marker error: RMS=0.0158776, max=0.0323096 (L.Bicep)
# Frame 350 (t=1.75):	total squared error = 0.00944041, marker error: RMS=0.0155583, max=0.0327533 (L.Bicep)
# Frame 351 (t=1.755):	total squared error = 0.00923772, marker error: RMS=0.0153904, max=0.0326684 (L.Bicep)
# Frame 352 (t=1.76):	total squared error = 0.00920972, marker error: RMS=0.0153671, max=0.0326511 (L.Bicep)
# Frame 353 (t=1.765):	total squared error = 0.00933005, marker error: RMS=0.0154671, max=0.0320679 (L.Bicep)
# Frame 354 (t=1.77):	total squared error = 0.00891513, marker error: RMS=0.0151193, max=0.034921 (L.Bicep)
# Frame 355 (t=1.775):	total squared error = 0.00883589, marker error: RMS=0.015052, max=0.0342645 (L.Bicep)
# Frame 356 (t=1.78):	total squared error = 0.00881246, marker error: RMS=0.015032, max=0.0344655 (L.Bicep)
# Frame 357 (t=1.785):	total squared error = 0.00898883, marker error: RMS=0.0151817, max=0.0339327 (L.Bicep)
# Frame 358 (t=1.79):	total squared error = 0.00872413, marker error: RMS=0.0149565, max=0.0358467 (L.Bicep)
# Frame 359 (t=1.795):	total squared error = 0.00879787, marker error: RMS=0.0150195, max=0.0354165 (L.Bicep)
# Frame 360 (t=1.8):	total squared error = 0.00904538, marker error: RMS=0.0152293, max=0.0352052 (L.Bicep)
# Frame 361 (t=1.805):	total squared error = 0.00949074, marker error: RMS=0.0155998, max=0.0352069 (L.Bicep)
# Frame 362 (t=1.81):	total squared error = 0.00926407, marker error: RMS=0.0154123, max=0.0378939 (L.Bicep)
# Frame 363 (t=1.815):	total squared error = 0.00949463, marker error: RMS=0.0156029, max=0.0375552 (L.Bicep)
# Frame 364 (t=1.82):	total squared error = 0.00995448, marker error: RMS=0.0159763, max=0.0373783 (L.Bicep)
# Frame 365 (t=1.825):	total squared error = 0.00951201, marker error: RMS=0.0156172, max=0.0369769 (L.Bicep)
# Frame 366 (t=1.83):	total squared error = 0.00995479, marker error: RMS=0.0159766, max=0.0368204 (L.Bicep)
# Frame 367 (t=1.835):	total squared error = 0.0106281, marker error: RMS=0.016508, max=0.0366625 (L.Bicep)
# Frame 368 (t=1.84):	total squared error = 0.0107111, marker error: RMS=0.0165724, max=0.0364066 (L.Bicep)
# Frame 369 (t=1.845):	total squared error = 0.0107389, marker error: RMS=0.0165939, max=0.0380386 (L.Bicep)
# Frame 370 (t=1.85):	total squared error = 0.0112647, marker error: RMS=0.0169953, max=0.0374989 (L.Bicep)
# Frame 371 (t=1.855):	total squared error = 0.0122035, marker error: RMS=0.0176893, max=0.0375435 (L.Bicep)
# Frame 372 (t=1.86):	total squared error = 0.0126719, marker error: RMS=0.0180255, max=0.0372667 (L.Bicep)
# Frame 373 (t=1.865):	total squared error = 0.0135043, marker error: RMS=0.0186082, max=0.037367 (L.Bicep)
# Frame 374 (t=1.87):	total squared error = 0.0141124, marker error: RMS=0.0190225, max=0.0404805 (L.Bicep)
# Frame 375 (t=1.875):	total squared error = 0.0151544, marker error: RMS=0.0197123, max=0.0400861 (L.Bicep)
# Frame 376 (t=1.88):	total squared error = 0.0149555, marker error: RMS=0.0195825, max=0.037128 (R.TH1)
# Frame 377 (t=1.885):	total squared error = 0.015868, marker error: RMS=0.0201711, max=0.0396452 (R.Knee)
# Frame 378 (t=1.89):	total squared error = 0.0173475, marker error: RMS=0.0210904, max=0.0431286 (R.Knee)
# Frame 379 (t=1.895):	total squared error = 0.0109061, marker error: RMS=0.0167226, max=0.0374371 (R.Heel)
# Frame 380 (t=1.9):	total squared error = 0.0103902, marker error: RMS=0.0163223, max=0.0339676 (R.Heel)
# Frame 381 (t=1.905):	total squared error = 0.00998257, marker error: RMS=0.0159989, max=0.034839 (L.Bicep)
# Frame 382 (t=1.91):	total squared error = 0.00989406, marker error: RMS=0.0159278, max=0.0346483 (L.Bicep)
# Frame 383 (t=1.915):	total squared error = 0.00984161, marker error: RMS=0.0158855, max=0.0344057 (L.Bicep)
# Frame 384 (t=1.92):	total squared error = 0.00964292, marker error: RMS=0.0157243, max=0.034899 (L.Bicep)
# Frame 385 (t=1.925):	total squared error = 0.00935772, marker error: RMS=0.0154901, max=0.034539 (L.Bicep)
# Frame 386 (t=1.93):	total squared error = 0.00931021, marker error: RMS=0.0154507, max=0.0342108 (L.Bicep)
# Frame 387 (t=1.935):	total squared error = 0.00890223, marker error: RMS=0.0151084, max=0.0337389 (L.Bicep)
# Frame 388 (t=1.94):	total squared error = 0.00872812, marker error: RMS=0.0149599, max=0.0342682 (L.Bicep)
# Frame 389 (t=1.945):	total squared error = 0.00875683, marker error: RMS=0.0149845, max=0.0337816 (L.Bicep)
# Frame 390 (t=1.95):	total squared error = 0.00866464, marker error: RMS=0.0149054, max=0.0343237 (L.Bicep)
# Frame 391 (t=1.955):	total squared error = 0.00843629, marker error: RMS=0.0147077, max=0.0336534 (L.Bicep)
# Frame 392 (t=1.96):	total squared error = 0.00858753, marker error: RMS=0.0148389, max=0.033404 (L.Bicep)
# Frame 393 (t=1.965):	total squared error = 0.0085664, marker error: RMS=0.0148206, max=0.0333707 (R.Bicep)
# Frame 394 (t=1.97):	total squared error = 0.00837076, marker error: RMS=0.0146504, max=0.0332927 (L.Bicep)
# Frame 395 (t=1.975):	total squared error = 0.00848436, marker error: RMS=0.0147495, max=0.0326471 (L.Bicep)
# Frame 396 (t=1.98):	total squared error = 0.00845111, marker error: RMS=0.0147206, max=0.0340273 (R.Bicep)
# Frame 397 (t=1.985):	total squared error = 0.00855958, marker error: RMS=0.0148147, max=0.0326473 (R.Bicep)
# Frame 398 (t=1.99):	total squared error = 0.00841073, marker error: RMS=0.0146854, max=0.0340591 (R.Bicep)
# Frame 399 (t=1.995):	total squared error = 0.0085081, marker error: RMS=0.0147701, max=0.0331899 (R.Bicep)
# Frame 400 (t=2):	total squared error = 0.00843424, marker error: RMS=0.0147059, max=0.0341727 (R.Bicep)
# Frame 401 (t=2.005):	total squared error = 0.00787792, marker error: RMS=0.0142126, max=0.0305202 (R.Bicep)
# Frame 402 (t=2.01):	total squared error = 0.00787183, marker error: RMS=0.0142071, max=0.0316315 (R.Bicep)
# Frame 403 (t=2.015):	total squared error = 0.00818155, marker error: RMS=0.0144839, max=0.0313246 (R.Bicep)
# Frame 404 (t=2.02):	total squared error = 0.00804405, marker error: RMS=0.0143617, max=0.0323221 (R.Bicep)
# Frame 405 (t=2.025):	total squared error = 0.00807951, marker error: RMS=0.0143933, max=0.0312293 (R.Bicep)
# Frame 406 (t=2.03):	total squared error = 0.00767046, marker error: RMS=0.0140242, max=0.029859 (R.Bicep)
# Frame 407 (t=2.035):	total squared error = 0.00783975, marker error: RMS=0.0141781, max=0.0289376 (R.Bicep)
# Frame 408 (t=2.04):	total squared error = 0.00757857, marker error: RMS=0.01394, max=0.0291951 (R.Bicep)
# Frame 409 (t=2.045):	total squared error = 0.00764073, marker error: RMS=0.013997, max=0.0283534 (R.Bicep)
# Frame 410 (t=2.05):	total squared error = 0.00784091, marker error: RMS=0.0141792, max=0.0295752 (R.Bicep)
# Frame 411 (t=2.055):	total squared error = 0.0078585, marker error: RMS=0.0141951, max=0.0293387 (R.Bicep)
# Frame 412 (t=2.06):	total squared error = 0.00802711, marker error: RMS=0.0143465, max=0.0293028 (R.Bicep)
# Frame 413 (t=2.065):	total squared error = 0.00878855, marker error: RMS=0.0150116, max=0.0326138 (L.Wrist)
# Frame 414 (t=2.07):	total squared error = 0.0080041, marker error: RMS=0.014326, max=0.0286007 (R.Bicep)
# Frame 415 (t=2.075):	total squared error = 0.00843884, marker error: RMS=0.0147099, max=0.0275999 (R.Bicep)
# Frame 416 (t=2.08):	total squared error = 0.00800556, marker error: RMS=0.0143273, max=0.0287621 (R.Bicep)
# Frame 417 (t=2.085):	total squared error = 0.00840368, marker error: RMS=0.0146792, max=0.0280523 (R.Bicep)
# Frame 418 (t=2.09):	total squared error = 0.00818172, marker error: RMS=0.014484, max=0.0285232 (R.Bicep)
# Frame 419 (t=2.095):	total squared error = 0.00872653, marker error: RMS=0.0149585, max=0.0283055 (R.Bicep)
# Frame 420 (t=2.1):	total squared error = 0.00914866, marker error: RMS=0.015316, max=0.0302267 (R.Bicep)
# Frame 421 (t=2.105):	total squared error = 0.0102028, marker error: RMS=0.0161744, max=0.033651 (L.Wrist)
# Frame 422 (t=2.11):	total squared error = 0.0089952, marker error: RMS=0.015187, max=0.0315116 (R.Bicep)
# Frame 423 (t=2.115):	total squared error = 0.00928867, marker error: RMS=0.0154328, max=0.0313634 (R.Bicep)
# Frame 424 (t=2.12):	total squared error = 0.0101648, marker error: RMS=0.0161443, max=0.0312279 (R.Bicep)
# Frame 425 (t=2.125):	total squared error = 0.0098696, marker error: RMS=0.0159081, max=0.029465 (R.Bicep)
# Frame 426 (t=2.13):	total squared error = 0.0104688, marker error: RMS=0.0163838, max=0.0310469 (R.Bicep)
# Frame 427 (t=2.135):	total squared error = 0.0105688, marker error: RMS=0.0164619, max=0.0310509 (R.Bicep)
# Frame 428 (t=2.14):	total squared error = 0.0107975, marker error: RMS=0.0166391, max=0.0318597 (R.Bicep)
# Frame 429 (t=2.145):	total squared error = 0.0108479, marker error: RMS=0.0166779, max=0.0302548 (R.Bicep)
# Frame 430 (t=2.15):	total squared error = 0.0113698, marker error: RMS=0.0170744, max=0.0319404 (R.Bicep)
# Frame 431 (t=2.155):	total squared error = 0.0115063, marker error: RMS=0.0171765, max=0.0304636 (R.Bicep)
# Frame 432 (t=2.16):	total squared error = 0.0123849, marker error: RMS=0.0178203, max=0.0303079 (R.Bicep)
# Frame 433 (t=2.165):	total squared error = 0.0120124, marker error: RMS=0.0175502, max=0.0295413 (R.Bicep)
# Frame 434 (t=2.17):	total squared error = 0.0126659, marker error: RMS=0.0180213, max=0.0312184 (R.Bicep)
# Frame 435 (t=2.175):	total squared error = 0.0125623, marker error: RMS=0.0179474, max=0.0299837 (L.Bicep)
# Frame 436 (t=2.18):	total squared error = 0.0126388, marker error: RMS=0.018002, max=0.030363 (R.Bicep)
# Frame 437 (t=2.185):	total squared error = 0.0133978, marker error: RMS=0.0185346, max=0.0323014 (R.Heel)
# Frame 438 (t=2.19):	total squared error = 0.0147345, marker error: RMS=0.0194372, max=0.0364808 (R.Heel)
# Frame 439 (t=2.195):	total squared error = 0.0133976, marker error: RMS=0.0185345, max=0.0304442 (R.Bicep)
# Frame 440 (t=2.2):	total squared error = 0.0133411, marker error: RMS=0.0184954, max=0.0309889 (L.Bicep)
# Frame 441 (t=2.205):	total squared error = 0.0139889, marker error: RMS=0.0189391, max=0.0348353 (R.Heel)
# Frame 442 (t=2.21):	total squared error = 0.0142913, marker error: RMS=0.0191427, max=0.0357141 (R.Heel)
# Frame 443 (t=2.215):	total squared error = 0.0153752, marker error: RMS=0.0198554, max=0.0398311 (R.Heel)
# Frame 444 (t=2.22):	total squared error = 0.0167905, marker error: RMS=0.0207491, max=0.0434041 (R.Heel)
# Frame 445 (t=2.225):	total squared error = 0.0170598, marker error: RMS=0.0209148, max=0.0443442 (R.Heel)
# Frame 446 (t=2.23):	total squared error = 0.0184184, marker error: RMS=0.0217317, max=0.0471998 (R.Heel)
# Frame 447 (t=2.235):	total squared error = 0.00771697, marker error: RMS=0.0140667, max=0.0304644 (L.Bicep)
# Frame 448 (t=2.24):	total squared error = 0.00739924, marker error: RMS=0.013774, max=0.0311052 (L.Bicep)
# Frame 449 (t=2.245):	total squared error = 0.00740012, marker error: RMS=0.0137749, max=0.0316945 (L.Bicep)
# Frame 450 (t=2.25):	total squared error = 0.00692891, marker error: RMS=0.0133291, max=0.0347368 (L.Bicep)
# Frame 451 (t=2.255):	total squared error = 0.00698935, marker error: RMS=0.0133871, max=0.034076 (L.Bicep)
# Frame 452 (t=2.26):	total squared error = 0.00725573, marker error: RMS=0.0136398, max=0.0347879 (L.Bicep)
# Frame 453 (t=2.265):	total squared error = 0.00756153, marker error: RMS=0.0139243, max=0.0348353 (L.Bicep)
# Frame 454 (t=2.27):	total squared error = 0.0071726, marker error: RMS=0.0135614, max=0.0360265 (L.Bicep)
# Frame 455 (t=2.275):	total squared error = 0.00764889, marker error: RMS=0.0140045, max=0.0358419 (L.Bicep)
# Frame 456 (t=2.28):	total squared error = 0.00740101, marker error: RMS=0.0137757, max=0.0351747 (L.Bicep)
# Frame 457 (t=2.285):	total squared error = 0.00755432, marker error: RMS=0.0139176, max=0.0350411 (L.Bicep)
# Frame 458 (t=2.29):	total squared error = 0.0066703, marker error: RMS=0.013078, max=0.0340056 (L.Bicep)
# Frame 459 (t=2.295):	total squared error = 0.00652343, marker error: RMS=0.0129332, max=0.0331306 (L.Bicep)
# Frame 460 (t=2.3):	total squared error = 0.00644687, marker error: RMS=0.0128571, max=0.0318922 (L.Bicep)
# Frame 461 (t=2.305):	total squared error = 0.00645269, marker error: RMS=0.0128629, max=0.0312575 (L.Bicep)
# Frame 462 (t=2.31):	total squared error = 0.00647807, marker error: RMS=0.0128881, max=0.0297523 (L.Bicep)
# Frame 463 (t=2.315):	total squared error = 0.00661079, marker error: RMS=0.0130195, max=0.0291394 (L.Bicep)
# Frame 464 (t=2.32):	total squared error = 0.00607695, marker error: RMS=0.0124828, max=0.0284529 (L.Bicep)
# Frame 465 (t=2.325):	total squared error = 0.00606861, marker error: RMS=0.0124742, max=0.0266057 (L.Bicep)
# Frame 466 (t=2.33):	total squared error = 0.00599135, marker error: RMS=0.0123945, max=0.0263797 (L.Bicep)
# Frame 467 (t=2.335):	total squared error = 0.00607651, marker error: RMS=0.0124823, max=0.0247074 (L.Bicep)
# Frame 468 (t=2.34):	total squared error = 0.00617239, marker error: RMS=0.0125804, max=0.0243302 (L.Bicep)
# Frame 469 (t=2.345):	total squared error = 0.00640891, marker error: RMS=0.0128192, max=0.0225356 (L.Bicep)
# Frame 470 (t=2.35):	total squared error = 0.00699603, marker error: RMS=0.0133935, max=0.0228424 (R.TH3)
# Frame 471 (t=2.355):	total squared error = 0.00723274, marker error: RMS=0.0136182, max=0.023558 (R.Bicep)
# Frame 472 (t=2.36):	total squared error = 0.007716, marker error: RMS=0.0140658, max=0.0249636 (L.Wrist)
# [info] InverseKinematicsTool completed 473 frames in 9 second(s)
# [info] COMAKInverseKinematics complete.
# [info] Finished in 438 second(s) (7 minute(s), 18 second(s))
# [info] Printed results to: ./results/comak-inverse-kinematics
# [info]
